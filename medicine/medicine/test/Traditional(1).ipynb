# %%
with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:2524]:
        print(line, end='')

# %%
with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:2524]:
        if line.split():
            print(line, end='')

# %%
rows = ""
with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:2524]:
        if line.split():
            rows += ",".join(line.replace(" ","").split("\n"))
        else:
            if len(rows.split(",")) > 2:
                print(rows)
            rows =""
    print(rows)

# %%
rows = []
with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:2524]:
        if line.split():
            for x in line.replace(" ","").split("\n"):
                if x:
                    rows.append(x)
            #print(line.replace(" ","").split("\n"))
        else:
            if len(rows) > 2:
                n = len(rows)
                while len(rows):
                    x = rows.pop(0)
                    if "【釋名】" in x:
                        print("【釋名】", x.split("【釋名】")[1])
                    elif "【氣味】" in x:
                        print("【氣味】", x.split("【氣味】")[1])
                    elif "【主治】" in x:
                        print("【主治】", x.split("【主治】")[0], "," , x.split("【主治】")[1])
                    elif "【附方】" in x:
                        for y in x.split("【附方】"):
                            if y:
                                print("【附方】", y)
                        if len(rows):
                            rows[0] += "【附方】"
                    if n - len(rows) == 1:
                        print("【藥名】", x)
                #print(rows)
            rows = []
    if len(rows) > 2:
        n = len(rows)
        while len(rows):
            x = rows.pop(0)
            if "【釋名】" in x:
                print("【釋名】", x.split("【釋名】")[1])
            elif "【氣味】" in x:
                print("【氣味】", x.split("【氣味】")[1])
            elif "【主治】" in x:
                print("【主治】", x.split("【主治】")[0], "," , x.split("【主治】")[1])
            elif "【附方】" in x:
                for y in x.split("【附方】"):
                    if y:
                        print("【附方】", y)
                    if len(rows):
                        rows[0] += "【附方】"
            if n - len(rows) == 1:
                print("【藥名】", x)
    #print(rows)

# %%
rows = ""
with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:3017]:
        if line.split():
            rows += ",".join(line.replace(" ","").split("\n"))
        else:
            if len(rows.split(",")) > 2:
                print(rows)
            rows =""
    print(rows)

# %%
rows = []
with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:3017]:
        if line.split():
            for x in line.replace(" ","").split("\n"):
                if x:
                    rows.append(x)
            #print(line.replace(" ","").split("\n"))
        else:
            if len(rows) > 2:
                n = len(rows)
                while len(rows):
                    x = rows.pop(0)
                    if "【釋名】" in x:
                        print("【釋名】", x.split("【釋名】")[1])
                    elif "【氣味】" in x:
                        print("【氣味】", x.split("【氣味】")[1])
                    elif "【主治】" in x:
                        print("【主治】", x.split("【主治】")[0], "," , x.split("【主治】")[1])
                    elif "【附方】" in x:
                        for y in x.split("【附方】"):
                            if y:
                                print("【附方】", y)
                        if len(rows):
                            rows[0] += "【附方】"
                    if n - len(rows) == 1:
                        print("【藥名】", x)
                #print(rows)
            rows = []
    if len(rows) > 2:
        n = len(rows)
        while len(rows):
            x = rows.pop(0)
            if "【釋名】" in x:
                print("【釋名】", x.split("【釋名】")[1])
            elif "【氣味】" in x:
                print("【氣味】", x.split("【氣味】")[1])
            elif "【主治】" in x:
                print("【主治】", x.split("【主治】")[0], "," , x.split("【主治】")[1])
            elif "【附方】" in x:
                for y in x.split("【附方】"):
                    if y:
                        print("【附方】", y)
                    if len(rows):
                        rows[0] += "【附方】"
            if n - len(rows) == 1:
                print("【藥名】", x)
    #print(rows)

# %%
import pandas as pd

df1 = pd.DataFrame(columns=["藥名", "釋名", "氣味", "主治", "附方"])

rows = []
with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:3017]:
        if line.split():
            for x in line.replace(" ","").split("\n"):
                if x:
                    rows.append(x)
        else:
            if len(rows) > 2:
                n = len(rows)
                while len(rows):
                    x = rows.pop(0)
                    if "【釋名】" in x:
                        #print("【釋名】", x.split("【釋名】")[1])
                        for y in x.split("【釋名】"):
                            if y:
                                df1.loc[df1.shape[0]]["釋名"] += y
                    elif "【氣味】" in x:
                        #print("【氣味】", x.split("【氣味】")[1])
                        for y in x.split("【氣味】"):
                            if y:
                                df1.loc[df1.shape[0]]["氣味"] += y
                    elif "【主治】" in x:
                        #print("【主治】", x.split("【主治】")[0], "," , x.split("【主治】")[1])
                        for y in x.split("【主治】"):
                            if y:
                                df1.loc[df1.shape[0]]["主治"] += "," + y
                    elif "【附方】" in x:
                        for y in x.split("【附方】"):
                            if y:
                                #print("【附方】", y)
                                df1.loc[df1.shape[0]]["附方"] += "," + y
                        if len(rows):
                            rows[0] += "【附方】"
                    if n - len(rows) == 1:
                        #print("【藥名】", x)
                        df1.loc[df1.shape[0] + 1] = {"藥名" : "", "釋名" : "", "氣味" : "", "主治" : "", "附方" : ""}
                        df1.loc[df1.shape[0]]["藥名"] = x
            rows = []
    if len(rows) > 2:
        n = len(rows)
        while len(rows):
            x = rows.pop(0)
            if "【釋名】" in x:
                #print("【釋名】", x.split("【釋名】")[1])
                for y in x.split("【釋名】"):
                    if y:
                        df1.loc[df1.shape[0]]["釋名"] += y
            elif "【氣味】" in x:
                #print("【氣味】", x.split("【氣味】")[1])
                for y in x.split("【氣味】"):
                    if y:
                        df1.loc[df1.shape[0]]["氣味"] += y
            elif "【主治】" in x:
                #print("【主治】", x.split("【主治】")[0], "," , x.split("【主治】")[1])
                for y in x.split("【主治】"):
                    if y:
                        df1.loc[df1.shape[0]]["主治"] += "," + y
            elif "【附方】" in x:
                for y in x.split("【附方】"):
                    if y:
                        #print("【附方】", y)
                        df1.loc[df1.shape[0]]["附方"] += "," + y
                    if len(rows):
                        rows[0] += "【附方】"
            if n - len(rows) == 1:
                #print("【藥名】", x)
                df1.loc[df1.shape[0] + 1] = {"藥名" : "", "釋名" : "", "氣味" : "", "主治" : "", "附方" : ""}
                df1.loc[df1.shape[0]]["藥名"] = x
#df1.loc[df1.shape[0] + 1] = {"藥名" : 1, "釋名" : [1, 2, 3]}

#df1.loc[1]['col2'].extend((4,5))

# df1.loc[df1.shape[0] + 1] =  {"藥名" : '1', "釋名" : [1, 2, 3], "氣味" : "", "主治" : "", "附方" : ""}
# df1.loc[df1.shape[0]]["氣味"] = "1"
# df"1.loc[df1.shape[0]]1
df1.drop(df1[df1["釋名"] == ""][df1["氣味"] == ""][df1["主治"] == ""][df1["附方"] == ""].index)

# %%
rows = []
with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:]:
        if line.split():
            for x in line.replace(" ","").split("\n"):
                if x:
                    rows.append(x)
            #print(line.replace(" ","").split("\n"))
        else:
            if len(rows) > 2:
                n = len(rows)
                while len(rows):
                    x = rows.pop(0)
                    if "【釋名】" in x:
                        print("【釋名】", x.split("【釋名】")[1])
                    elif "【氣味】" in x:
                        print("【氣味】", x.split("【氣味】")[1])
                    elif "【主治】" in x:
                        print("【主治】", x.split("【主治】")[0], "," , x.split("【主治】")[1])
                    elif "【附方】" in x:
                        for y in x.split("【附方】"):
                            if y:
                                print("【附方】", y)
                        if len(rows):
                            rows[0] += "【附方】"
                    if n - len(rows) == 1:
                        print("【藥名】", x)
                #print(rows)
            rows = []
    if len(rows) > 2:
        n = len(rows)
        while len(rows):
            x = rows.pop(0)
            if "【釋名】" in x:
                print("【釋名】", x.split("【釋名】")[1])
            elif "【氣味】" in x:
                print("【氣味】", x.split("【氣味】")[1])
            elif "【主治】" in x:
                print("【主治】", x.split("【主治】")[0], "," , x.split("【主治】")[1])
            elif "【附方】" in x:
                for y in x.split("【附方】"):
                    if y:
                        print("【附方】", y)
                if len(rows):
                    rows[0] += "【附方】"
            if n - len(rows) == 1:
                print("【藥名】", x)
    #print(rows)

# %%
import pandas as pd

df1 = pd.DataFrame(columns=["藥名", "釋名", "氣味", "主治", "附方"])

rows = []
with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:]:
        if line.split():
            for x in line.replace(" ","").split("\n"):
                if x:
                    rows.append(x)
        else:
            if len(rows) > 2:
                n = len(rows)
                while len(rows):
                    x = rows.pop(0)
                    if "【釋名】" in x:
                        #print("【釋名】", x.split("【釋名】")[1])
                        for y in x.split("【釋名】"):
                            if y:
                                df1.loc[df1.shape[0]]["釋名"] += y
                    elif "【氣味】" in x:
                        #print("【氣味】", x.split("【氣味】")[1])
                        for y in x.split("【氣味】"):
                            if y:
                                df1.loc[df1.shape[0]]["氣味"] += y
                    elif "【主治】" in x:
                        #print("【主治】", x.split("【主治】")[0], "," , x.split("【主治】")[1])
                        for y in x.split("【主治】"):
                            if y:
                                df1.loc[df1.shape[0]]["主治"] += y + ":"
                        df1.loc[df1.shape[0]]["主治"] += ","
                    elif "【附方】" in x:
                        for y in x.split("【附方】"):
                            if y:
                                #print("【附方】", y)
                                df1.loc[df1.shape[0]]["附方"] += "," + y
                        if len(rows):
                            rows[0] += "【附方】"
                    if n - len(rows) == 1:
                        #print("【藥名】", x)
                        df1.loc[df1.shape[0] + 1] = {"藥名" : "", "釋名" : "", "氣味" : "", "主治" : "", "附方" : ""}
                        df1.loc[df1.shape[0]]["藥名"] = x
            rows = []
    if len(rows) > 2:
        n = len(rows)
        while len(rows):
            x = rows.pop(0)
            if "【釋名】" in x:
                #print("【釋名】", x.split("【釋名】")[1])
                for y in x.split("【釋名】"):
                    if y:
                        df1.loc[df1.shape[0]]["釋名"] += y
            elif "【氣味】" in x:
                #print("【氣味】", x.split("【氣味】")[1])
                for y in x.split("【氣味】"):
                    if y:
                        df1.loc[df1.shape[0]]["氣味"] += y
            elif "【主治】" in x:
                #print("【主治】", x.split("【主治】")[0], "," , x.split("【主治】")[1])
                for y in x.split("【主治】"):
                    if y:
                        df1.loc[df1.shape[0]]["主治"] += y + ":"
                df1.loc[df1.shape[0]]["主治"] += ","
            elif "【附方】" in x:
                for y in x.split("【附方】"):
                    if y:
                        #print("【附方】", y)
                        df1.loc[df1.shape[0]]["附方"] += "," + y
                    if len(rows):
                        rows[0] += "【附方】"
            if n - len(rows) == 1:
                #print("【藥名】", x)
                df1.loc[df1.shape[0] + 1] = {"藥名" : "", "釋名" : "", "氣味" : "", "主治" : "", "附方" : ""}
                df1.loc[df1.shape[0]]["藥名"] = x
#df1.loc[df1.shape[0] + 1] = {"藥名" : 1, "釋名" : [1, 2, 3]}

#df1.loc[1]['col2'].extend((4,5))

# df1.loc[df1.shape[0] + 1] =  {"藥名" : '1', "釋名" : [1, 2, 3], "氣味" : "", "主治" : "", "附方" : ""}
# df1.loc[df1.shape[0]]["氣味"] = "1"
# df"1.loc[df1.shape[0]]1
df2 = df1.drop(df1[df1["釋名"] == ""][df1["氣味"] == ""][df1["主治"] == ""][df1["附方"] == ""].index)

# %%
df2[df2["附方"] != ""][["藥名", "附方"]]

# %%
df3 = pd.DataFrame(columns=["藥名", "附方"])
for i in df2[df2["附方"] != ""].index:
    for x in df2.loc[i]["附方"].split(","):
        if x:
            df3.loc[df3.shape[0] + 1] = {"藥名" : df2.loc[i]["藥名"], "附方" : x}

df3

# %%
df3.to_csv("./data/繁體附方.csv", index=0)

# %%
import pandas as pd

df = pd.DataFrame(columns=["名詞", "長度"])
sets = set()

with open('./data/專有名詞.txt', 'r') as file:
    for line in file.readlines():
        if len(line) > 2:
            sets.add(line)
    for x in sets:
        df.loc[df.shape[0] + 1] = {"名詞" : x.strip(), "長度" : len(x.strip())}
df.sort_values(["長度"], ascending=0)["名詞"].to_csv("./data/專有名詞(改).txt", index=0, header=0)

# %%
import pandas as pd

df = pd.DataFrame(columns=["藥名", "權重"])
sets = set()

with open('./data/藥名.txt', 'r') as file:
    for line in file.readlines():
        #if len(line) > 2:
        sets.add(line)
    for x in sets:
        df.loc[df.shape[0] + 1] = {"藥名" : x.rstrip("\n"), "權重" : len(x.rstrip("\n"))}
df.sort_values(["權重"], ascending=0)["藥名"].to_csv("./data/藥名(改).txt", sep=" ", index=0, header=0)
#df.sort_values(["權重"], ascending=0)

# %%
import re
import jieba, jieba.analyse

temp = ''
rows = []
jieba.analyse.TFIDF(idf_path=None)
jieba.analyse.set_stop_words("./data/專有名詞(改).txt")
jieba.load_userdict("./data/藥名(改)_Ver2.txt")

with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:]:
        if line:
            temp += line.strip()
            
        #if line.rsplit("\n"):
        #    print(line)
            #for x in line.rsplit("\n"):
            #    if x:
#         temp += line
    for x in re.sub("(，|。|（|《|》|）|【|】|∶|；|、|？)", ',', temp).split(","):
        tags = jieba.analyse.extract_tags(x)
        if tags:
            rows.extend(tags)
    #print(rows)
with open('./data/斷詞.txt', 'w') as f:
    for x in rows:
        f.write(x)
        f.write("\n")

# %%
import logging
from gensim.models import word2vec

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
Sentence = word2vec.LineSentence('./data/斷詞.txt')
model = word2vec.Word2Vec(Sentence, size=100, min_count=2, window=10)
model.save("./data/word2vec.model")
model.wv.save_word2vec_format("./data/word2vec.txt", binary=False)

# %%
res = model.wv.most_similar('甘草', topn = 20)
for item in res:
    print(item[0] + "," + str(item[1]))

# %%
import re

def tokenize(sentence):
    temp = []
    for x in stop_words:
        if x in sentence:
            for y in sentence.split(x):
                if y:
                    temp.append(y)
            break
    for x in userdict:
        if x in sentence:
            tmp = sentence.split(x)
            tmp.insert(1, x)
            for y in tmp:
                if y:
                    temp.append(y)
            break
    if temp:
        return temp
    else:
        temp.append(sentence)
        return temp

temp = ''
rows = []
stop_words = []
userdict = []

with open('./data/專有名詞(改).txt', 'r') as file:
    for line in file.readlines():
        stop_words.append(line.strip())
with open('./data/藥名(改).txt', 'r') as file:
    for line in file.readlines():
        userdict.append(line.strip())

with open('./data/本草綱目.txt', 'r') as file:
    for line in file.readlines()[2406:]:
        if line.strip() != '':
            temp += line.strip()
            
        #if line.rsplit("\n"):
        #    print(line)
            #for x in line.rsplit("\n"):
            #    if x:
#         temp += line
    for x in re.sub("(，|。|（|《|》|）|【|】|∶|；|、|？)", ',', temp).split(","):
        if x:
            tags = tokenize(x)
            if tags:
#                 print(tags)
                rows.extend(tags)
#     print(rows)
with open('./data/斷詞(改).txt', 'w') as f:
    for x in rows:
        f.write(x)
        f.write("\n")

# %%
import logging
from gensim.models import word2vec

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
Sentence = word2vec.LineSentence('./data/斷詞(改).txt')
model = word2vec.Word2Vec(Sentence, size=250, min_count=2, window=5, sg=0)
model.save("./data/word2vec.model")
model.wv.save_word2vec_format("./data/word2vec(改).txt", binary=False)
# Out:
# 2018-05-14 19:05:17,020 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2018-05-14 19:05:17,022 : INFO : collecting all words and their counts
# 2018-05-14 19:05:17,024 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-05-14 19:05:17,097 : INFO : PROGRESS: at sentence #10000, processed 10251 words, keeping 7120 word types
# 2018-05-14 19:05:17,149 : INFO : PROGRESS: at sentence #20000, processed 20418 words, keeping 13406 word types
# 2018-05-14 19:05:17,195 : INFO : PROGRESS: at sentence #30000, processed 30598 words, keeping 18768 word types
# 2018-05-14 19:05:17,242 : INFO : PROGRESS: at sentence #40000, processed 40835 words, keeping 24699 word types
# 2018-05-14 19:05:17,288 : INFO : PROGRESS: at sentence #50000, processed 51024 words, keeping 30045 word types
# 2018-05-14 19:05:17,334 : INFO : PROGRESS: at sentence #60000, processed 61138 words, keeping 34938 word types
# 2018-05-14 19:05:17,381 : INFO : PROGRESS: at sentence #70000, processed 71283 words, keeping 39656 word types
# 2018-05-14 19:05:17,429 : INFO : PROGRESS: at sentence #80000, processed 81423 words, keeping 44643 word types
# 2018-05-14 19:05:17,474 : INFO : PROGRESS: at sentence #90000, processed 91606 words, keeping 49520 word types
# 2018-05-14 19:05:17,520 : INFO : PROGRESS: at sentence #100000, processed 101805 words, keeping 54390 word types
# 2018-05-14 19:05:17,566 : INFO : PROGRESS: at sentence #110000, processed 112022 words, keeping 59067 word types
# 2018-05-14 19:05:17,612 : INFO : PROGRESS: at sentence #120000, processed 122201 words, keeping 63524 word types
# 2018-05-14 19:05:17,658 : INFO : PROGRESS: at sentence #130000, processed 132393 words, keeping 68175 word types
# 2018-05-14 19:05:17,704 : INFO : PROGRESS: at sentence #140000, processed 142592 words, keeping 72588 word types
# 2018-05-14 19:05:17,750 : INFO : PROGRESS: at sentence #150000, processed 152813 words, keeping 77144 word types
# 2018-05-14 19:05:17,796 : INFO : PROGRESS: at sentence #160000, processed 163087 words, keeping 82150 word types
# 2018-05-14 19:05:17,842 : INFO : PROGRESS: at sentence #170000, processed 173372 words, keeping 87170 word types
# 2018-05-14 19:05:17,890 : INFO : PROGRESS: at sentence #180000, processed 183518 words, keeping 91987 word types
# 2018-05-14 19:05:17,936 : INFO : PROGRESS: at sentence #190000, processed 193725 words, keeping 96654 word types
# 2018-05-14 19:05:17,982 : INFO : PROGRESS: at sentence #200000, processed 204032 words, keeping 101856 word types
# 2018-05-14 19:05:18,028 : INFO : PROGRESS: at sentence #210000, processed 214250 words, keeping 106843 word types
# 2018-05-14 19:05:18,074 : INFO : PROGRESS: at sentence #220000, processed 224455 words, keeping 111747 word types
# 2018-05-14 19:05:18,120 : INFO : PROGRESS: at sentence #230000, processed 234658 words, keeping 116651 word types
# 2018-05-14 19:05:18,167 : INFO : PROGRESS: at sentence #240000, processed 244874 words, keeping 121210 word types
# 2018-05-14 19:05:18,215 : INFO : PROGRESS: at sentence #250000, processed 255028 words, keeping 125744 word types
# 2018-05-14 19:05:18,263 : INFO : PROGRESS: at sentence #260000, processed 265299 words, keeping 130440 word types
# 2018-05-14 19:05:18,311 : INFO : PROGRESS: at sentence #270000, processed 275570 words, keeping 135215 word types
# 2018-05-14 19:05:18,358 : INFO : PROGRESS: at sentence #280000, processed 285905 words, keeping 140120 word types
# 2018-05-14 19:05:18,404 : INFO : PROGRESS: at sentence #290000, processed 296207 words, keeping 144849 word types
# 2018-05-14 19:05:18,451 : INFO : PROGRESS: at sentence #300000, processed 306462 words, keeping 149602 word types
# 2018-05-14 19:05:18,497 : INFO : PROGRESS: at sentence #310000, processed 316675 words, keeping 154196 word types
# 2018-05-14 19:05:18,544 : INFO : PROGRESS: at sentence #320000, processed 326930 words, keeping 158956 word types
# 2018-05-14 19:05:18,591 : INFO : PROGRESS: at sentence #330000, processed 337187 words, keeping 164052 word types
# 2018-05-14 19:05:18,607 : INFO : collected 166141 word types from a corpus of 340603 raw words and 333356 sentences
# 2018-05-14 19:05:18,608 : INFO : Loading a fresh vocabulary
# 2018-05-14 19:05:18,710 : INFO : min_count=2 retains 18835 unique words (11% of original 166141, drops 147306)
# 2018-05-14 19:05:18,711 : INFO : min_count=2 leaves 193297 word corpus (56% of original 340603, drops 147306)
# 2018-05-14 19:05:18,805 : INFO : deleting the raw counts dictionary of 166141 items
# 2018-05-14 19:05:18,808 : INFO : sample=0.001 downsamples 36 most-common words
# 2018-05-14 19:05:18,810 : INFO : downsampling leaves estimated 173310 word corpus (89.7% of prior 193297)
# 2018-05-14 19:05:18,859 : INFO : estimated required memory for 18835 words and 250 dimensions: 47087500 bytes
# 2018-05-14 19:05:18,860 : INFO : resetting layer weights
# 2018-05-14 19:05:19,301 : INFO : training model with 3 workers on 18835 vocabulary and 250 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-05-14 19:05:20,361 : INFO : EPOCH 1 - PROGRESS: at 17.66% examples, 28644 words/s, in_qsize 5, out_qsize 1
# 2018-05-14 19:05:21,366 : INFO : EPOCH 1 - PROGRESS: at 52.96% examples, 45959 words/s, in_qsize 3, out_qsize 2
# 2018-05-14 19:05:21,896 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-14 19:05:21,901 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-14 19:05:21,905 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-14 19:05:21,906 : INFO : EPOCH - 1 : training on 340603 raw words (173175 effective words) took 2.6s, 66584 effective words/s
# 2018-05-14 19:05:23,042 : INFO : EPOCH 2 - PROGRESS: at 23.58% examples, 40979 words/s, in_qsize 3, out_qsize 3
# 2018-05-14 19:05:24,167 : INFO : EPOCH 2 - PROGRESS: at 67.62% examples, 56049 words/s, in_qsize 6, out_qsize 0
# 2018-05-14 19:05:24,355 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-14 19:05:24,364 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-14 19:05:24,367 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-14 19:05:24,368 : INFO : EPOCH - 2 : training on 340603 raw words (173381 effective words) took 2.3s, 74199 effective words/s
# 2018-05-14 19:05:25,385 : INFO : EPOCH 3 - PROGRESS: at 20.62% examples, 35459 words/s, in_qsize 5, out_qsize 0
# 2018-05-14 19:05:26,421 : INFO : EPOCH 3 - PROGRESS: at 64.69% examples, 55915 words/s, in_qsize 5, out_qsize 0
# 2018-05-14 19:05:26,689 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-14 19:05:26,697 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-14 19:05:26,701 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-14 19:05:26,702 : INFO : EPOCH - 3 : training on 340603 raw words (173260 effective words) took 2.3s, 74308 effective words/s
# 2018-05-14 19:05:27,712 : INFO : EPOCH 4 - PROGRESS: at 17.66% examples, 30272 words/s, in_qsize 6, out_qsize 0
# 2018-05-14 19:05:28,867 : INFO : EPOCH 4 - PROGRESS: at 67.63% examples, 55410 words/s, in_qsize 4, out_qsize 1
# 2018-05-14 19:05:29,080 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-14 19:05:29,083 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-14 19:05:29,100 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-14 19:05:29,101 : INFO : EPOCH - 4 : training on 340603 raw words (173376 effective words) took 2.4s, 72346 effective words/s
# 2018-05-14 19:05:30,117 : INFO : EPOCH 5 - PROGRESS: at 23.58% examples, 40884 words/s, in_qsize 4, out_qsize 0
# 2018-05-14 19:05:31,170 : INFO : EPOCH 5 - PROGRESS: at 64.69% examples, 55488 words/s, in_qsize 4, out_qsize 1
# 2018-05-14 19:05:31,522 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-05-14 19:05:31,526 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-05-14 19:05:31,527 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-05-14 19:05:31,528 : INFO : EPOCH - 5 : training on 340603 raw words (173279 effective words) took 2.4s, 71487 effective words/s
# 2018-05-14 19:05:31,529 : INFO : training on a 1703015 raw words (866471 effective words) took 12.2s, 70866 effective words/s
# 2018-05-14 19:05:31,546 : INFO : saving Word2Vec object under ./data/word2vec.model, separately None
# 2018-05-14 19:05:31,547 : INFO : not storing attribute vectors_norm
# 2018-05-14 19:05:31,548 : INFO : not storing attribute cum_table
# 2018-05-14 19:05:32,132 : INFO : saved ./data/word2vec.model
# 2018-05-14 19:05:32,134 : INFO : storing 18835x250 projection weights into ./data/word2vec(改).txt

# %%
res = model.wv.most_similar(['甘草'], topn = 20)
for item in res:
    print(item[0] + "," + str(item[1]))
# Out:
# 出秦,0.23851144313812256
# 葵葉,0.22997814416885376
# 塗頭,0.22163806855678558
# 梁州,0.22043177485466003
# 石城,0.22024405002593994
# 木履,0.21891219913959503
# 虎者,0.21530559659004211
# 既久,0.21195702254772186
# 忽病,0.21148726344108582
# 辛能,0.21075065433979034
# 赤白二種,0.21034681797027588
# 有黃色,0.20976509153842926
# 其花,0.2093983143568039
# 如豹,0.20824062824249268
# 服一錢,0.20757317543029785
# 李食,0.2071676254272461
# 水怪,0.20613497495651245
# 食多,0.2056688815355301
# 掘土,0.20560777187347412
# 回陽,0.2050836682319641

# %%
import pandas as pd

df = pd.DataFrame(columns=["藥物1", "藥物2", "相似度"])
userdict = []

with open('./data/藥名(改).txt', 'r') as file:
    for line in file.readlines():
        userdict.append(line.strip())
        
with open('./data/word2vec(改).txt', 'r') as file:
    for x in file.readlines()[1:]:
        if x.split()[0] in userdict:
            res = model.wv.most_similar(x.split()[0], topn = 20)
            for y1, y2 in res[0:1]:
                if y1 in userdict:
                    print(x.split()[0], y1, y2)
#                     df.loc[df.shape[0] + 1] = {"藥物1" : x.split()[0], "藥物2" : y1, "相似度" : y2}
# df
# df.to_csv("./data/藥物word2vec.csv", index=0)
# Out:
# 附子 翹根 0.2623589038848877
# 雄黃 青葙子 0.24363328516483307
# 滑石 馬肉 0.26053765416145325
# 烏梅 鼍甲 0.2551453113555908
# 五倍子 龍須 0.2343687266111374
# 胡桃 小麻子 0.2338975965976715
# 苦酒 豆汁 0.2809268534183502
# 柴胡 天豆 0.2393755316734314
# 松脂 朴硝 0.2163718342781067
# 柏葉 白藓 0.2596821188926697
# 豌豆 刺豬苓 0.256328821182251
# 蒼耳 金盞銀台 0.2431255728006363
# 沒藥 陳思岌 0.2586985230445862
# 東流水 蘿蔔 0.23690848052501678
# 青鹽 蜚虻 0.23460733890533447
# 魚骨 金盞銀台 0.2661972939968109
# 白膠 野鴨 0.264577180147171
# 戎鹽 綠礬 0.23426498472690582
# 大青 樗雞 0.26969897747039795
# 曾青 鐵落 0.2476971447467804
# 白鹽 接骨草 0.2541484832763672
# 土瓜 敗醬 0.2554892599582672
# 牛角 齊蛤 0.22952227294445038
# 鼠尾 羞天草 0.2528584599494934
# 蠶砂 常春藤 0.24815455079078674
# 蝼蛄 馬先蒿 0.25267723202705383
# 螺蛳 地錦 0.22234630584716797
# 白花蛇 桃子 0.24709580838680267
# 枸杞根 土青木香 0.2608575224876404
# 馬肉 滑石 0.26053762435913086
# 胡豆 佛耳草 0.23730984330177307
# 諸石 木蓮 0.2820672392845154
# 桑根白皮 小豆 0.25625669956207275
# 檀香 雞肉 0.23561173677444458
# 青葙子 雄黃 0.24363330006599426
# 石葦 木饅頭 0.23784519731998444
# 木蓮 諸石 0.2820672392845154
# 野鴨 白膠 0.264577180147171
# 硬石膏 諸石 0.24467550218105316
# 紫芝 天名精 0.22823797166347504
# 蠶豆 白蔹 0.24120590090751648
# 馬目毒公 牛脂 0.23426298797130585
# 款冬 冬瓜 0.2465258687734604
# 漢椒 苋菜 0.22652579843997955
# 飛生 漿水 0.24607622623443604
# 苦藥子 玄石 0.2327757328748703
# 桃子 白花蛇 0.24709579348564148
# 馬先蒿 蝼蛄 0.25267723202705383
# 常春藤 蠶砂 0.24815459549427032
# 金盞銀台 魚骨 0.2661973237991333
# 豆汁 苦酒 0.28092682361602783
# 刺豬苓 豌豆 0.256328821182251
# 白藓 柏葉 0.2596821188926697
# 土青木香 枸杞根 0.26085755228996277
# 生魚 羊踯躅 0.24045826494693756
# 山大黃 豕首 0.24975872039794922
# 天豆 柴胡 0.239375501871109
# 藥實根 白花蛇 0.2284606695175171
# 胡蒜 雞骨 0.24069473147392273
# 樗雞 大青 0.26969897747039795
# 蔥實 石龍 0.25551629066467285
# 接骨草 白鹽 0.2541485130786896
# 荩草 鹽鹵 0.2423708736896515
# 陳思岌 沒藥 0.2586985230445862
# 駝脂 艾葉 0.2337387502193451
# 獐頭 磁石 0.2356099635362625

# %%
userdict = []

with open('./data/藥名(改).txt', 'r') as file:
    for line in file.readlines():
        userdict.append(line.strip())
        
with open('./data/word2vec(改).txt', 'r') as file:
    for x in file.readlines()[1:]:
        if x.split()[0] in userdict:
            res = model.wv.most_similar(x.split()[0], topn = 20)
            for y1, y2 in res[0:1]:
                if y1 in userdict:
                    print(x.split()[0], y1, y2)

# %%
import pandas as pd
import re,jieba

df = pd.read_csv("./data/compound.csv", names=["名稱", "內容"])
df["斷詞"] = ""
df.head()
# Out:
#      名稱                                                 內容 斷詞
# 0   滅瘢痕                                   以凍淩頻熨之，良。（《千金方》）
# 1  闢禳時疫                                    半天河水，飲之。（《醫林集要》
# 2  身體白駁                    取樹木孔中水洗之，搗桂末唾和敷之，日再上。（張文仲《備急方》）
# 3  目不得瞑  乃陽氣盛不得入于陰，陰氣虛，故目不得瞑。治法飲以半夏湯，用流水千裏外者八升，揚之萬遍，取其清...
# 4  汗後奔豚  茯苓桂枝甘草大棗湯，治發汗後臍下悸，欲作奔豚者。茯苓一兩，炙甘草二錢半，桂枝三錢，大棗二枚。...

# %%
tmp = ""
temp = []
for i in df["名稱"][1]:
    tmp += " ".join(i)
    temp.append(tmp)
print(temp)
# Out:
# ['闢', '闢禳', '闢禳時', '闢禳時疫']

# %%
import pandas as pd
import re,jieba,jieba.analyse

df = pd.read_csv("./data/compound.csv", names=["名稱", "內容"])
jieba.analyse.set_stop_words("./data/專有名詞(改).txt")
jieba.load_userdict("./data/藥名(改).txt")
jieba.analyse.TFIDF(idf_path=None)
df["斷詞"] = ""
df.head()

for i in range(df.shape[0]):
    #print(" ".join(df.loc[i]))
    tmp = ""
    rows = []
    for x in re.sub("(，|。|（|《|》|）|【|】|∶|；|、|？)", ',', " ".join(df.loc[i])).split(","):
        if x:
#             seg_list = jieba.analyse.extract_tags(x)
            seg_list = jieba.cut_for_search(x)
            tmp += " ".join(seg_list)
    #print(i,tmp)
    df.loc[i]["斷詞"] = tmp

# %%
df["斷詞"].head()
# Out:
# 0                        滅 瘢痕   以 凍 淩 頻 熨 之良千金 金方 千金方
# 1                              闢 禳 時疫   半天 河水飲 之醫林 集要
# 2           身體 白駁   取樹木孔 中 水洗 之搗桂末 唾 和 敷 之日 再 上張文仲備急方
# 3    目 不得 瞑   乃陽氣 盛 不得 入于 陰陰氣虛故目 不得 瞑治法 飲以 半夏 湯用 流水...
# 4    汗 後 奔豚   茯苓 桂枝 甘草 大棗 湯治發 汗後臍 下悸欲作 奔豚 者茯苓 一兩炙 甘...
# Name: 斷詞, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

tf_vectorizer = CountVectorizer()
tf = tf_vectorizer.fit_transform(df["斷詞"])
lda = LatentDirichletAllocation(n_components=4, learning_method='online')
lda.fit(tf)

n_top_words = 20

tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)

import pyLDAvis
import pyLDAvis.sklearn

pyLDAvis.enable_notebook()
pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer)
# Out:
# Topic #0:
# 小兒 一錢 一兩 一個 金瘡 燒灰 腫毒 調服 研末 牙齒 梧子 癰疽 摘要 少許 血痢 半錢 發背 螫傷 五日 硫黃
# Topic #1:
# 總錄 霍亂 婦人 下血 生薑 方見 風蟲 鲫魚 身面 蠱毒 洗淨 咬傷 麝香 漿水 血崩 消渴 豬肉 發熱 湯火傷 乾薑
# Topic #2:
# 小便 小兒 子母 梧子每服 湯下 二錢 地黃 吐血 空心 生瘡 傷寒 初起 腳氣 方寸 雞子 燒研 心鑑 楊梅 集要 牙疳
# Topic #3:
# 腫痛 小兒 良方 簡方 一升 本草 喉痹 惡瘡 下痢 破傷 搗汁 中風 痔瘡 煮汁 半兩 鼻中 赤白 頭瘡 二升 大黃
# /home/tmu/anaconda3/lib/python3.6/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 2      25.439022        1       1 -0.079587  0.121300
# 0      25.091680        1       2 -0.061895 -0.056109
# 3      24.841752        1       3 -0.003889 -0.104903
# 1      24.627546        1       4  0.145372  0.039712, topic_info=      Category        Freq  Term       Total  loglift  logprob
# term
# 19695  Default   71.000000    腫痛   71.000000  30.0000  30.0000
# 10270  Default  206.000000    小兒  206.000000  29.0000  29.0000
# 18951  Default   48.000000    總錄   48.000000  28.0000  28.0000
# 1599   Default   48.000000    一錢   48.000000  27.0000  27.0000
# 10186  Default   46.000000    小便   46.000000  26.0000  26.0000
# 169    Default   41.000000    一兩   41.000000  25.0000  25.0000
# 9939   Default   38.000000    子母   38.000000  24.0000  24.0000
# 23119  Default   36.000000    霍亂   36.000000  23.0000  23.0000
# 20257  Default   35.000000    良方   35.000000  22.0000  22.0000
# 18441  Default   33.000000    簡方   33.000000  21.0000  21.0000
# 550    Default   30.000000    一升   30.000000  20.0000  20.0000
# 9880   Default   41.000000    婦人   41.000000  19.0000  19.0000
# 14585  Default   29.000000    湯下   29.000000  18.0000  18.0000
# 4372   Default   29.000000    二錢   29.000000  17.0000  17.0000
# 8872   Default   29.000000    地黃   29.000000  16.0000  16.0000
# 12745  Default   28.000000    本草   28.000000  15.0000  15.0000
# 8141   Default   28.000000    吐血   28.000000  14.0000  14.0000
# 13131  Default   41.000000  梧子每服   41.000000  13.0000  13.0000
# 112    Default   27.000000    一個   27.000000  12.0000  12.0000
# 22646  Default   25.000000    金瘡   25.000000  11.0000  11.0000
# 15657  Default   25.000000    燒灰   25.000000  10.0000  10.0000
# 19670  Default   24.000000    腫毒   24.000000   9.0000   9.0000
# 21719  Default   23.000000    調服   23.000000   8.0000   8.0000
# 16259  Default   23.000000    生瘡   23.000000   7.0000   7.0000
# 5649   Default   22.000000    傷寒   22.000000   6.0000   6.0000
# 17894  Default   21.000000    研末   21.000000   5.0000   5.0000
# 11143  Default   21.000000    惡瘡   21.000000   4.0000   4.0000
# 18184  Default   35.000000    空心   35.000000   3.0000   3.0000
# 2703   Default   19.000000    下血   19.000000   2.0000   2.0000
# 6511   Default   20.000000    初起   20.000000   1.0000   1.0000
# ...        ...         ...   ...         ...      ...      ...
# 2703    Topic4   19.343848    下血   19.814015   1.3773  -6.1112
# 12066   Topic4   16.938176    方見   17.392437   1.3748  -6.2440
# 16297   Topic4   17.031335    生薑   17.495525   1.3744  -6.2385
# 23540   Topic4   13.357111    風蟲   13.806811   1.3682  -6.4815
# 22162   Topic4   13.043888    身面   13.496297   1.3672  -6.5053
# 23911   Topic4   13.237761    鲫魚   13.728774   1.3649  -6.4905
# 14182   Topic4   12.111360    洗淨   12.563717   1.3646  -6.5794
# 21316   Topic4   12.132486    蠱毒   12.586488   1.3646  -6.5777
# 8287    Topic4   12.067000    咬傷   12.518899   1.3645  -6.5831
# 21361   Topic4   11.829413    血崩   12.281651   1.3638  -6.6030
# 14913   Topic4   11.951359    漿水   12.417198   1.3631  -6.5927
# 23985   Topic4   11.958056    麝香   12.435346   1.3622  -6.5922
# 14377   Topic4   11.562834    消渴   12.033703   1.3614  -6.6258
# 14721   Topic4   10.361717   湯火傷   10.807991   1.3591  -6.7355
# 17027   Topic4   10.686866    發熱   11.153116   1.3586  -6.7046
# 21944   Topic4   10.695236    豬肉   11.191053   1.3560  -6.7038
# 19390   Topic4    8.921861    胞衣    9.384024   1.3508  -6.8851
# 4045    Topic4    9.516035    乾薑   10.009844   1.3507  -6.8206
# 23351   Topic4    8.779092    頭上    9.235495   1.3506  -6.9012
# 22206   Topic4    8.435302    轉筋    8.880932   1.3498  -6.9412
# 12470   Topic4    8.769138   服二錢    9.236585   1.3494  -6.9023
# 23517   Topic4    8.497794    風痰    8.955954   1.3488  -6.9338
# 19874   Topic4    8.204042    腹痛    8.659112   1.3473  -6.9690
# 14720   Topic4    8.033106    湯火    8.479181   1.3473  -6.9900
# 21252   Topic4    7.944824    螫人    8.390376   1.3467  -7.0011
# 18874   Topic4    7.987330    綠豆    8.445801   1.3455  -6.9957
# 13509   Topic4    7.715485    每服    8.168167   1.3443  -7.0304
# 5814    Topic4    7.550434    入耳    7.996092   1.3440  -7.0520
# 7023    Topic4    8.248213    半升    8.742655   1.3431  -6.9636
# 9880    Topic4   34.915148    婦人   41.320163   1.2329  -5.5207
#
# [166 rows x 6 columns], token_table=       Topic      Freq Term
# term
# 112        2  0.990920   一個
# 169        2  0.997080   一兩
# 550        3  0.992400   一升
# 1260       1  0.911602   一枚
# 1599       2  0.996311   一錢
# 1985       1  0.916409   七枚
# 2123       1  0.990877   三十
# 2446       2  0.988114   三錢
# 2672       1  0.273397   下痢
# 2672       3  0.717667   下痢
# 2703       4  0.958917   下血
# 3103       2  0.926225   不止
# 3713       3  0.950056   中風
# 3749       2  0.928732   丹毒
# 4045       4  0.999017   乾薑
# 4076       1  0.991499   事親
# 4215       3  0.963073   二升
# 4372       1  0.989628   二錢
# 4791       2  0.927803   五日
# 4971       2  0.988857   亦可
# 5442       2  0.929862   作痛
# 5649       1  0.989347   傷寒
# 5814       4  1.000489   入耳
# 6511       1  0.997847   初起
# 6954       3  0.948862   半兩
# 7023       4  0.915054   半升
# 7228       2  0.956691   半錢
# 7420       2  0.964658   去皮
# 7490       1  0.923213   反胃
# 7732       3  0.981482   口瘡
# ...      ...       ...  ...
# 21252      4  0.953473   螫人
# 21254      2  0.966835   螫傷
# 21316      4  0.953403   蠱毒
# 21361      4  0.977067   血崩
# 21404      2  0.998704   血痢
# 21639      1  0.957387   調下
# 21719      2  0.967800   調服
# 21944      4  0.982928   豬肉
# 22027      3  0.937810   赤白
# 22098      1  0.998181   走馬
# 22162      4  0.963227   身面
# 22206      4  0.900806   轉筋
# 22434      3  0.921747   酒下
# 22458      3  0.932100   酒服
# 22646      2  0.968205   金瘡
# 23038      1  0.935882   集要
# 23067      1  0.992510   雞子
# 23119      4  0.989021   霍亂
# 23351      4  0.974501   頭上
# 23381      3  0.950607   頭瘡
# 23402      3  0.911883   頭風
# 23502      3  0.896186   風病
# 23517      4  0.893261   風痰
# 23540      4  0.941564   風蟲
# 23646      2  0.974054   飲水
# 23911      4  0.946916   鲫魚
# 23985      4  0.964991   麝香
# 24186      3  0.702685   黃連
# 24186      4  0.263507   黃連
# 24324      3  0.963008   鼻中
#
# [145 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 1, 4, 2])

# %%
from sklearn.decomposition import LatentDirichletAllocation

lda = LatentDirichletAllocation(n_components=5)
lda.fit(tf)
# Out:
# /home/tmu/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7, learning_method=None,
#              learning_offset=10.0, max_doc_update_iter=100, max_iter=10,
#              mean_change_tol=0.001, n_components=5, n_jobs=1,
#              n_topics=None, perp_tol=0.1, random_state=None,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

n_top_words = 20

tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topic #0:
# 金方 千金方 之千金 麻子 總錄 麝香 霍亂 末每服 之肘後方 不止 大豆 本草 湯調 反胃 心痛 一盞 南星 痔瘡 末以 一枚
# Topic #1:
# 大每服 梧子 不止 桐子 梧桐 梧桐子 二十 三十 五十 吐血 小兒 兩爲 綠豆 自然 二錢 秘錄 甘草 溫酒 飲服 大每
# Topic #2:
# 一切 出血 良方 不可 消渴 妊娠 十九 四十 入耳 腹中 四十九 蓖麻 牙痛 槟榔 一大 痛不可忍 之即 蜈蚣 螫傷 雞子
# Topic #3:
# 小便 末每服 外台秘要 兩爲 梧子 不通 疼痛 下痢 簡方 腹痛 咳嗽 羊肉 作痛 各一 各半 大小 湯服 少許 乳香 麻油
# Topic #4:
# 小兒 分爲 方寸 腫痛 之聖惠方 汲水 匕日 一錢 末酒服 手足 不下 調服 傷寒 末每服 初起 不止 中風 喉痹 半爲 癰疽

# %%
import pyLDAvis
import pyLDAvis.sklearn

pyLDAvis.enable_notebook()
pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 1      23.045871        1       1  0.171854 -0.004878
# 4      19.514582        1       2 -0.069410 -0.176629
# 3      19.456897        1       3  0.053493  0.018154
# 0      19.129808        1       4 -0.068832  0.100494
# 2      18.852842        1       5 -0.087105  0.062859, topic_info=      Category        Freq  Term       Total  loglift  logprob
# term
# 30990  Default  199.000000    金方  199.000000  30.0000  30.0000
# 10269  Default  181.000000   千金方  181.000000  29.0000  29.0000
# 14160  Default  242.000000    小兒  242.000000  28.0000  28.0000
# 9530   Default  128.000000    分爲  128.000000  27.0000  27.0000
# 13145  Default  168.000000   大每服  168.000000  26.0000  26.0000
# 14147  Default  106.000000    小便  106.000000  25.0000  25.0000
# 16516  Default   94.000000    方寸   94.000000  24.0000  24.0000
# 18476  Default  163.000000    梧子  163.000000  23.0000  23.0000
# 27346  Default   80.000000    腫痛   80.000000  22.0000  22.0000
# 12882  Default   75.000000  外台秘要   75.000000  21.0000  21.0000
# 18427  Default   74.000000    桐子   74.000000  20.0000  20.0000
# 447    Default   64.000000    一切   64.000000  19.0000  19.0000
# 18480  Default   73.000000    梧桐   73.000000  18.0000  18.0000
# 18481  Default   73.000000   梧桐子   73.000000  17.0000  17.0000
# 4651   Default   64.000000   之千金   64.000000  16.0000  16.0000
# 8455   Default  111.000000    兩爲  111.000000  15.0000  15.0000
# 33097  Default   60.000000    麻子   60.000000  14.0000  14.0000
# 17690  Default  139.000000   末每服  139.000000  13.0000  13.0000
# 3562   Default  143.000000    不止  143.000000  12.0000  12.0000
# 26386  Default   52.000000    總錄   52.000000  11.0000  11.0000
# 3740   Default   48.000000    不通   48.000000  10.0000  10.0000
# 6131   Default   70.000000    二十   70.000000   9.0000   9.0000
# 23186  Default   46.000000    疼痛   46.000000   8.0000   8.0000
# 2276   Default   67.000000    三十   67.000000   7.0000   7.0000
# 9407   Default   40.000000    出血   40.000000   6.0000   6.0000
# 5332   Default   41.000000  之聖惠方   41.000000   5.0000   5.0000
# 31748  Default   40.000000    霍亂   40.000000   4.0000   4.0000
# 27874  Default   37.000000    良方   37.000000   3.0000   3.0000
# 3291   Default   37.000000    下痢   37.000000   2.0000   2.0000
# 3486   Default   36.000000    不可   36.000000   1.0000   1.0000
# ...        ...         ...   ...         ...      ...      ...
# 20035   Topic5   31.616951    消渴   32.151489   1.6517  -5.8637
# 13684   Topic5   29.576336    妊娠   30.116308   1.6504  -5.9304
# 10125   Topic5   24.716088    十九   25.232452   1.6478  -6.1099
# 7952    Topic5   23.987943    入耳   24.505812   1.6471  -6.1398
# 12299   Topic5   23.452730   四十九   23.968592   1.6467  -6.1624
# 27450   Topic5   23.779050    腹中   24.308716   1.6465  -6.1485
# 22296   Topic5   21.122653    牙痛   21.647306   1.6440  -6.2670
# 18610   Topic5   20.233233    槟榔   20.766089   1.6425  -6.3100
# 23310   Topic5   18.213127  痛不可忍   18.731566   1.6404  -6.4152
# 4662    Topic5   17.598939    之即   18.126993   1.6389  -6.4495
# 28976   Topic5   17.299649    蜈蚣   17.823102   1.6387  -6.4667
# 29041   Topic5   17.046904    螫傷   17.567668   1.6384  -6.4814
# 10169   Topic5   16.582159    十四   17.103897   1.6375  -6.5090
# 31685   Topic5   16.665526    雞子   17.205039   1.6366  -6.5040
# 905     Topic5   16.526785    一小   17.065025   1.6365  -6.5124
# 6019    Topic5   15.769653    二七   16.299247   1.6355  -6.5593
# 411     Topic5   16.067461   一分爲   16.618317   1.6348  -6.5405
# 3543    Topic5   15.768768    不拘   16.318870   1.6342  -6.5593
# 28514   Topic5   21.414096    蓖麻   22.168613   1.6339  -6.2533
# 14415   Topic5   14.933593    尿血   15.462458   1.6337  -6.6137
# 18060   Topic5   15.439837    朱砂   15.989930   1.6335  -6.5804
# 11997   Topic5   14.112121    咬傷   14.630144   1.6325  -6.6703
# 30326   Topic5   14.319716    身面   14.855096   1.6318  -6.6557
# 4456    Topic5   14.067104   之不過   14.593566   1.6318  -6.6735
# 21886   Topic5   14.273898    熟食   14.809904   1.6316  -6.6589
# 23131   Topic5   13.271367    疝氣   13.806730   1.6290  -6.7317
# 804     Topic5   18.434687    一大   21.320558   1.5231  -6.4031
# 12298   Topic5   23.997059    四十   37.823138   1.2135  -6.1394
# 15261   Topic5   15.605496    惡瘡   23.831826   1.2451  -6.5697
# 28515   Topic5   14.808931   蓖麻子   19.058702   1.4162  -6.6221
#
# [222 rows x 6 columns], token_table=       Topic      Freq Term
# term
# 8          1  0.954177   一丸
# 158        2  0.940071   一個
# 411        5  0.962793  一分爲
# 447        5  0.992247   一切
# 804        4  0.093806   一大
# 804        5  0.844256   一大
# 905        5  0.996190   一小
# 1020       3  0.959211   一斤
# 1210       2  0.208815   一枚
# 1210       4  0.783058   一枚
# 1397       4  0.969482   一盞
# 1584       2  0.976090   一錢
# 2276       1  0.855377   三十
# 2276       3  0.132731   三十
# 2512       1  0.958567   三服
# 3291       3  0.979470   下痢
# 3359       1  0.976326   下血
# 3424       2  0.992610   不下
# 3486       5  0.985107   不可
# 3525       1  0.951951   不得
# 3543       5  0.980460   不拘
# 3562       1  0.675546   不止
# 3562       2  0.153217   不止
# 3562       4  0.174110   不止
# 3740       3  0.995201   不通
# 4037       2  0.967052   中風
# 4230       1  0.988126  丸空心
# 4233       1  0.942613   丸米
# 4315       3  0.964290   丹毒
# 4456       5  0.959327  之不過
# ...      ...       ...  ...
# 28515      5  0.787042  蓖麻子
# 28643      4  0.973820   薤白
# 28968      2  0.962851   蜂房
# 28976      5  0.953818   蜈蚣
# 28985      4  0.934480   蜘蛛
# 29041      5  0.967687   螫傷
# 29123      4  0.935120   蠱毒
# 29230      1  0.941509   血痢
# 29723      2  0.996429   調服
# 30326      5  0.942438   身面
# 30384      4  0.919603   轉筋
# 30990      2  0.005013   金方
# 30990      4  0.992575   金方
# 31007      2  0.659059   金瘡
# 31007      4  0.292915   金瘡
# 31685      5  0.988083   雞子
# 31748      4  0.995129   霍亂
# 31854      3  0.992727   面上
# 31880      1  0.961635   面糊
# 32014      2  0.993805   頭瘡
# 32038      4  0.988831   頭風
# 32206      3  0.995366   風蟲
# 32375      1  0.961819   飲下
# 32488      1  0.968561   飲服
# 32571      4  0.905593   飲食
# 32888      3  0.950255   鬭煮
# 33069      4  0.838187   麝香
# 33069      5  0.146683   麝香
# 33097      4  0.989563   麻子
# 33108      3  0.981217   麻油
#
# [233 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 5, 4, 1, 3])

# %%
lda = LatentDirichletAllocation(n_components=4)

lda.fit(tf)

print_top_words(lda, tf_feature_names, n_top_words)

pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer)
# Out:
# /home/tmu/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# Topic #0:
# 大每服 梧子 兩爲 不止 末每服 桐子 梧桐 梧桐子 小兒 之千金 三十 二十 五十 金方 千金方 分爲 湯下 綠豆 下痢 咳嗽
# Topic #1:
# 疼痛 不可 手足 自然 不下 作痛 入耳 之肘後方 羊肉 槟榔 牙齒 末每服 腳氣 生瘡 摘要 雞子 咬傷 之不過 粳米 一斤
# Topic #2:
# 金方 千金方 小便 方寸 腫痛 小兒 不通 出血 秘錄 喉痹 匕日 良方 末每服 大豆 消渴 婦人 末酒服 腹中 本草 大小
# Topic #3:
# 小兒 分爲 外台秘要 一切 麻子 總錄 不止 之聖惠方 吐血 麝香 二錢 一錢 甘草 調服 簡方 霍亂 十九 四十九 惡瘡 四十
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 0      29.682055        1       1  0.171135 -0.021836
# 3      24.393011        1       2 -0.032937  0.147340
# 2      23.603078        1       3 -0.068271 -0.112517
# 1      22.321855        1       4 -0.069927 -0.012988, topic_info=      Category        Freq  Term       Total  loglift  logprob
# term
# 13145  Default  169.000000   大每服  169.000000  30.0000  30.0000
# 18476  Default  167.000000    梧子  167.000000  29.0000  29.0000
# 30990  Default  203.000000    金方  203.000000  28.0000  28.0000
# 14147  Default  104.000000    小便  104.000000  27.0000  27.0000
# 10269  Default  184.000000   千金方  184.000000  26.0000  26.0000
# 8455   Default  116.000000    兩爲  116.000000  25.0000  25.0000
# 16516  Default   94.000000    方寸   94.000000  24.0000  24.0000
# 27346  Default   80.000000    腫痛   80.000000  23.0000  23.0000
# 12882  Default   74.000000  外台秘要   74.000000  22.0000  22.0000
# 9530   Default  132.000000    分爲  132.000000  21.0000  21.0000
# 14160  Default  245.000000    小兒  245.000000  20.0000  20.0000
# 447    Default   65.000000    一切   65.000000  19.0000  19.0000
# 3562   Default  144.000000    不止  144.000000  18.0000  18.0000
# 18427  Default   74.000000    桐子   74.000000  17.0000  17.0000
# 18480  Default   73.000000    梧桐   73.000000  16.0000  16.0000
# 18481  Default   73.000000   梧桐子   73.000000  15.0000  15.0000
# 33097  Default   61.000000    麻子   61.000000  14.0000  14.0000
# 4651   Default   69.000000   之千金   69.000000  13.0000  13.0000
# 2276   Default   68.000000    三十   68.000000  12.0000  12.0000
# 6716   Default   65.000000    五十   65.000000  11.0000  11.0000
# 26386  Default   53.000000    總錄   53.000000  10.0000  10.0000
# 6131   Default   70.000000    二十   70.000000   9.0000   9.0000
# 3740   Default   47.000000    不通   47.000000   8.0000   8.0000
# 5332   Default   41.000000  之聖惠方   41.000000   7.0000   7.0000
# 9407   Default   40.000000    出血   40.000000   6.0000   6.0000
# 25450  Default   39.000000    秘錄   39.000000   5.0000   5.0000
# 20292  Default   46.000000    湯下   46.000000   4.0000   4.0000
# 3486   Default   36.000000    不可   36.000000   3.0000   3.0000
# 26327  Default   41.000000    綠豆   41.000000   2.0000   2.0000
# 23186  Default   45.000000    疼痛   45.000000   1.0000   1.0000
# ...        ...         ...   ...         ...      ...      ...
# 15568   Topic4   12.660414    折傷   13.151120   1.4616  -6.9478
# 15034   Topic4   12.599771    心腹   13.126012   1.4587  -6.9526
# 22721   Topic4   11.341866   生生編   11.865004   1.4545  -7.0577
# 17373   Topic4   11.001667    木瓜   11.512759   1.4542  -7.0882
# 26306   Topic4   11.441959   經驗方   11.998107   1.4521  -7.0490
# 25911   Topic4   13.209200    粳米   13.881285   1.4500  -6.9053
# 7562    Topic4    9.393370    作癢    9.892520   1.4478  -7.2462
# 24920   Topic4    8.867328    石英    9.351471   1.4464  -7.3039
# 28896   Topic4    7.905012    蚰蜒    8.391622   1.4399  -7.4188
# 23060   Topic4   11.861629    男子   12.612019   1.4383  -7.0129
# 11803   Topic4    8.029436    吐食    8.545686   1.4373  -7.4031
# 21777   Topic4    7.711803    煮粥    8.214007   1.4365  -7.4435
# 32499   Topic4   10.912107    飲水   11.623806   1.4364  -7.0964
# 10608   Topic4    9.646684    半煎   10.280998   1.4359  -7.2196
# 1020    Topic4   13.139128    一斤   14.034966   1.4336  -6.9107
# 24118   Topic4    7.243597    白石    7.746219   1.4325  -7.5061
# 21806   Topic4    7.058541    煮食    7.554267   1.4317  -7.5320
# 24335   Topic4    6.889306    百蟲    7.374598   1.4315  -7.5563
# 32169   Topic4    7.332528    風痛    7.855522   1.4307  -7.4939
# 3686    Topic4   12.915549    不能   14.260186   1.4006  -6.9278
# 23186   Topic4   37.688741    疼痛   45.059530   1.3210  -5.8569
# 27763   Topic4   28.197437    自然   34.818390   1.2887  -6.1470
# 26436   Topic4   21.330493    羊肉   27.834747   1.2335  -6.4261
# 5343    Topic4   22.080016  之肘後方   29.855918   1.1979  -6.3916
# 23131   Topic4   11.717837    疝氣   13.762863   1.3387  -7.0251
# 22731   Topic4   16.869323    生瘡   23.351784   1.1744  -6.6608
# 32972   Topic4   10.678032    鲫魚   13.715200   1.2493  -7.1181
# 10169   Topic4   11.483639    十四   17.038107   1.1051  -7.0453
# 17690   Topic4   19.207696   末每服  142.481350  -0.5043  -6.5309
# 20502   Topic4   11.713576    湯調   22.329058   0.8545  -7.0255
#
# [203 rows x 6 columns], token_table=       Topic      Freq  Term
# term
# 411        2  0.945218   一分爲
# 447        2  0.988713    一切
# 804        1  0.138550    一大
# 804        3  0.831301    一大
# 905        3  0.990891    一小
# 1020       1  0.071251    一斤
# 1020       4  0.926258    一斤
# 1397       1  0.949853    一盞
# 1584       2  0.997502    一錢
# 2276       1  0.991567    三十
# 2512       1  0.954600    三服
# 3291       1  0.979284    下痢
# 3359       2  0.987013    下血
# 3424       4  0.978993    不下
# 3486       4  0.998919    不可
# 3562       1  0.677961    不止
# 3562       2  0.318227    不止
# 3686       3  0.070125    不能
# 3686       4  0.911629    不能
# 3740       3  0.997777    不通
# 4037       2  0.957573    中風
# 4230       1  0.983820   丸空心
# 4315       1  0.969353    丹毒
# 4456       4  0.972386   之不過
# 4651       1  0.998099   之千金
# 4831       3  0.935490   之子母
# 4952       2  0.955303  之摘玄方
# 4983       2  0.414302    之日
# 4983       3  0.564957    之日
# 5016       1  0.988416  之普濟方
# ...      ...       ...   ...
# 27874      3  0.731388    良方
# 28515      2  0.982503   蓖麻子
# 28896      4  0.953332    蚰蜒
# 28968      3  0.860492    蜂房
# 28968      4  0.107562    蜂房
# 28976      2  0.991410    蜈蚣
# 29041      2  0.949930    螫傷
# 29123      3  0.937981    蠱毒
# 29723      2  0.986402    調服
# 30326      3  0.937697    身面
# 30384      3  0.922480    轉筋
# 30990      1  0.309466    金方
# 30990      3  0.687703    金方
# 31685      4  0.942690    雞子
# 31748      2  0.645516    霍亂
# 31748      3  0.173793    霍亂
# 31748      4  0.173793    霍亂
# 31854      2  0.952357    面上
# 32014      2  0.984134    頭瘡
# 32169      4  0.891093    風痛
# 32206      2  0.938017    風蟲
# 32375      1  0.997475    飲下
# 32499      4  0.946334    飲水
# 32888      3  0.972655    鬭煮
# 32972      1  0.218735    鲫魚
# 32972      4  0.802030    鲫魚
# 33069      1  0.324687    麝香
# 33069      2  0.669666    麝香
# 33097      2  0.995499    麻子
# 33404      3  0.964497    鼻中
#
# [213 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 4, 3, 2])

# %%
from gensim import models,corpora

dictionary=corpora.Dictionary(document.split() for document in df["斷詞"])  
corpus=[dictionary.doc2bow(doc.split()) for doc in df["斷詞"]]#generate the corpus  
tf_idf=models.TfidfModel(corpus)#the constructor  
  
#this may convert the docs into the TF-IDF space.  
#Here will convert all docs to TFIDF  
corpus_tfidf=tf_idf[corpus]  
  
#train the lsi model  
lsi=models.LsiModel(corpus_tfidf,id2word=dictionary,num_topics=10)  
topics=lsi.show_topics(num_words=20)  
for tpc in topics:  
    print(tpc)
# Out:
# /home/tmu/anaconda3/lib/python3.6/site-packages/scipy/sparse/sparsetools.py:20: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# (0, '-0.366*"金方" + -0.364*"千金方" + -0.227*"之千金" + -0.187*"敷" + -0.176*"爲" + -0.173*"和" + -0.168*"小兒" + -0.140*"瘡" + -0.137*"等" + -0.132*"黃" + -0.132*"一" + -0.121*"薑" + -0.105*"汁" + -0.100*"不止" + -0.099*"梧子" + -0.098*"丸" + -0.097*"分爲" + -0.095*"用" + -0.095*"大每服" + -0.093*"方"')
# (1, '0.451*"千金方" + 0.443*"金方" + 0.290*"之千金" + -0.181*"爲" + -0.150*"梧子" + -0.148*"一" + -0.138*"等" + -0.138*"大每服" + -0.134*"丸" + -0.118*"分爲" + -0.116*"薑" + -0.112*"黃" + -0.098*"不止" + -0.096*"汁" + -0.096*"兩爲" + -0.092*"方" + -0.091*"末每服" + -0.089*"用" + -0.084*"血" + -0.083*"下"')
# (2, '-0.382*"敷" + -0.322*"小兒" + -0.293*"瘡" + 0.201*"千金方" + 0.201*"金方" + 0.170*"梧子" + 0.154*"大每服" + 0.144*"丸" + -0.138*"塗" + -0.131*"之" + -0.126*"之聖惠方" + -0.115*"等" + -0.113*"疔" + -0.111*"方" + 0.107*"兩爲" + 0.106*"一" + 0.106*"不止" + 0.105*"桐子" + 0.104*"梧桐子" + 0.104*"梧桐"')
# (3, '-0.395*"等" + -0.349*"分爲" + -0.323*"不止" + -0.296*"衄" + -0.224*"血" + 0.170*"丸" + 0.151*"和" + 0.145*"大每服" + 0.143*"梧子" + -0.137*"吐血" + 0.131*"敷" + -0.129*"末每服" + 0.128*"小兒" + 0.103*"桐子" + 0.103*"梧桐子" + 0.102*"一" + 0.102*"梧桐" + -0.101*"鼻" + 0.085*"兩爲" + -0.083*"方寸"')
# (4, '0.441*"等" + 0.369*"分爲" + -0.285*"産" + -0.276*"不止" + -0.244*"後" + -0.219*"衄" + -0.204*"血" + 0.110*"大每服" + 0.107*"梧子" + 0.106*"丸" + -0.104*"秘錄" + -0.090*"吐血" + -0.078*"之肘後方" + 0.076*"桐子" + 0.076*"梧桐子" + -0.075*"小兒" + 0.075*"梧桐" + 0.075*"瘡" + -0.073*"飲" + -0.072*"鼻"')
# (5, '-0.430*"産" + -0.384*"後" + 0.324*"不止" + 0.311*"小兒" + 0.264*"衄" + 0.160*"血" + -0.142*"方寸" + 0.119*"吐血" + 0.097*"鼻" + 0.097*"黃" + -0.089*"腫痛" + -0.089*"等" + 0.082*"大每服" + 0.082*"丸" + 0.080*"敷" + 0.078*"梧子" + 0.077*"之聖惠方" + -0.073*"小便" + -0.073*"方" + -0.065*"匕日"')
# (6, '-0.507*"小兒" + 0.453*"瘡" + 0.200*"疔" + -0.193*"産" + -0.190*"秘錄" + -0.179*"分爲" + -0.171*"等" + 0.150*"腫痛" + -0.147*"後" + 0.121*"不止" + 0.115*"之" + 0.096*"衄" + 0.087*"爲" + 0.081*"腫毒" + 0.080*"痘" + -0.079*"之子母" + 0.072*"方" + 0.068*"貼" + 0.068*"上" + 0.062*"惡腫"')
# (7, '0.452*"瘡" + -0.292*"薑" + 0.244*"小兒" + -0.241*"汁" + 0.191*"産" + 0.180*"疔" + -0.158*"敷" + -0.142*"塗" + 0.142*"秘錄" + -0.142*"和" + 0.125*"下" + 0.118*"後" + 0.110*"痘" + -0.103*"小便" + -0.102*"外台秘要" + -0.097*"方" + 0.094*"梧桐" + 0.094*"桐子" + 0.094*"梧桐子" + -0.093*"之"')
# (8, '-0.504*"敷" + 0.218*"小兒" + -0.209*"産" + -0.192*"後" + -0.151*"和" + -0.145*"血" + 0.135*"煎" + 0.131*"汁" + 0.130*"之" + -0.124*"桐子" + -0.124*"梧桐" + -0.124*"梧桐子" + 0.123*"薑" + -0.120*"衄" + 0.109*"瘡" + -0.107*"丸" + -0.106*"大每服" + 0.102*"一" + -0.098*"不止" + 0.095*"爲"')
# (9, '-0.294*"汁" + 0.292*"爲" + -0.290*"薑" + -0.202*"塗" + 0.191*"小便" + 0.191*"方" + 0.183*"方寸" + -0.178*"後" + -0.170*"瘡" + 0.164*"敷" + -0.147*"産" + 0.138*"末每服" + -0.125*"生" + -0.118*"和" + 0.113*"腫痛" + 0.112*"不通" + -0.111*"梧子" + 0.103*"桐子" + 0.102*"梧桐" + 0.102*"梧桐子"')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
import matplotlib.pyplot as plt
import pyLDAvis
import pyLDAvis.sklearn

pyLDAvis.enable_notebook()
# %matplotlib inline

n_samples = 2000
n_features = 1000
n_topics = 10
n_top_words = 20

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()
    
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words='english')

tfidf = tfidf_vectorizer.fit_transform(df["斷詞"])

print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words='english')

tf = tf_vectorizer.fit_transform(df["斷詞"])

print("Fitting the NMF model with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))

nmf = NMF(n_components=n_topics, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)


print("\nTopics in NMF model:")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)
item_distribution = nmf.components_
item_distribution = item_distribution.T
plt.plot(item_distribution[:, 0], item_distribution[:, 1], "b*")  
plt.xlim((-1, 6))  
plt.ylim((-1, 6))

plt.title(u'the distribution of items (NMF)')  
count = 1  
for item in item_distribution:  
    plt.text(item[0], item[1], 'item '+str(count), bbox=dict(facecolor='red', alpha=0.2),)
    count += 1

plt.show()

print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_topics=n_topics, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)

lda.fit(tf)


print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer)
# Out:
# Extracting tf-idf features for NMF...
# Extracting tf features for LDA...
# Fitting the NMF model with tf-idf features, n_samples=2000 and n_features=1000...
#
# Topics in NMF model:
# Topic #0:
# 金方 千金方 之千金 瘥千金 癒千金 也千金 三服千金 雞子 丹毒 地黃 胡粉 方寸 雲母 苦酒 匕千金 霍亂 血出 伏龍肝 乾薑 婦人
# Topic #1:
# 小兒 秘錄 之子母 頭瘡 夜啼 口瘡 之聖惠方 丹毒 麝香 初生 重舌 驚風 之千金 豬脂 之外台 心鑑 少許 疳瘡 雞子 黍米
# Topic #2:
# 分爲 汲水 一字 末每用 末酒服 頭痛 事親 目生 末新 口瘡 牙疳 摘要 末冷水 末每以 僵蠶 楊梅 末吹 末水服 風蟲 末米
# Topic #3:
# 不止 吐血 血痢 地黃 鼻血 汲水 血出 血崩 下血 利方 瘧疾 霍亂 金瘡 服二錢聖惠方 冷水 五靈脂 之食醫心鏡 出血 生薑 水浸
# Topic #4:
# 梧子 大每服 兩爲 五十 三十 綠豆 二十 湯下 各一 丸白湯 大每 黃連 丸空心 末煉蜜丸 空心 末蜜丸 丸米 糊丸 各半 十五
# Topic #5:
# 腫痛 喉痹 咽喉 痔瘡 風牙 赤眼 代指 簡方 之普濟方 之乾即 麻油 調服 牙齒 搗汁 芡子 腳氣 末摻 石脂 之日 各半
# Topic #6:
# 小便 不通 童子小便 尿血 大小便 童子 大小 淋痛 良方 鬭煮 滑石 琥珀 出血 秘錄 水腫 槟榔 簡方 白濁 蒲黃 大便
# Topic #7:
# 末每服 兩爲 簡方 各一 湯調 二錢 溫酒 二錢米 半爲 二錢溫酒 石膏 汲水 三錢溫酒 傷寒 一兩爲 總錄 地黃 一錢米 方寸 牽牛
# Topic #8:
# 外台秘要 方寸 匕日 之秘要 末酒服 末水服 也秘要 一切 飲服 燒灰酒服 梁上 發熱 雄黃 金瘡 妊娠 出血 羚羊 羚羊角 羊角 蠱毒
# Topic #9:
# 桐子 梧桐子 梧桐 大每服 大每 三十 末蜜丸 五十 飲下 二十 和丸 兩爲 末糊丸 丸空心 大每米 婦人 末酒糊丸 白茯苓 搗丸 大每溫
# Fitting LDA models with tf features, n_samples=2000 and n_features=1000...
# /home/tmu/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# Topics in LDA model:
# Topic #0:
# 不可 末酒服 腹中 豬肉 痛不可忍 蜈蚣 之即 螫傷 二七 薑汁 尿血 蘿蔔 百合 人參 咬傷 冷水 漿水 鲫魚 不能 心鑑
# Topic #1:
# 梧子 大每服 兩爲 桐子 外台秘要 梧桐 梧桐子 三十 五十 各一 二十 之聖惠方 下痢 黃連 空心 湯下 大每 和丸 湯調 飲下
# Topic #2:
# 一切 麝香 四十 傷寒 十九 腫毒 入耳 四十九 生瘡 惡瘡 本草 湯洗 初起 糯米 腳氣 蚯蚓 摘要 咽喉 十四 黑豆
# Topic #3:
# 婦人 出血 金瘡 之日 飲服 中風 硫黃 雄黃 下血 破傷 一錢爲 大便 五靈脂 一小 末米 熟食 之摘玄方 楊梅 童便 二三
# Topic #4:
# 疼痛 末以 甘草 羊肉 作痛 自然 霍亂 生薑 牙齒 蜂房 面上 輕粉 一個 水浸 一斤 酒服 要略 薤白 不合 大棗
# Topic #5:
# 消渴 末入 大豆 半夏 小豆 少許 槟榔 乳汁 反胃 不得 牽牛 乳香 茴香 百一選方 魚骨 犀角 搗汁 百一 一枚 之立
# Topic #6:
# 小兒 分爲 末每服 麻子 一錢 手足 腹痛 調服 蓖麻 癰疽 效方 麻油 之普濟方 蓖麻子 乾薑 田螺 女人 牙疳 發背 菖蒲
# Topic #7:
# 不止 末每服 地黃 綠豆 良方 吐血 咳嗽 溫酒 不下 南星 各半 芡子 兩爲 大每服 一大 方見 丹毒 血痢 朱砂 一丸
# Topic #8:
# 小便 總錄 汲水 不通 簡方 秘錄 妊娠 大小 童子 小兒 一盞 鬭煮 初生 利方 霍亂 童子小便 一二 腰痛 大小便 羊角
# Topic #9:
# 金方 千金方 方寸 腫痛 之千金 雞子 匕日 之肘後方 喉痹 牙痛 心痛 煮汁 豬脂 痔瘡 風蟲 瘥千金 一分爲 真人 身面 末水服
# /home/tmu/anaconda3/lib/python3.6/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 1      17.998347        1       1  0.278750 -0.085733
# 9      11.289703        1       2 -0.151178  0.216250
# 7      11.133678        1       3  0.276979 -0.014565
# 6      10.880277        1       4  0.085434  0.249099
# 8       9.155701        1       5 -0.077079  0.146570
# 4       8.467673        1       6 -0.081450 -0.088852
# 2       8.394104        1       7 -0.112389 -0.098431
# 3       7.791075        1       8 -0.013341 -0.007692
# 5       7.580011        1       9 -0.094543 -0.178347
# 0       7.309431        1      10 -0.111184 -0.138299, topic_info=     Category        Freq  Term       Total  loglift  logprob
# term
# 376   Default  358.000000    小兒  358.000000  30.0000  30.0000
# 912   Default  295.000000    金方  295.000000  29.0000  29.0000
# 262   Default  268.000000   千金方  268.000000  28.0000  28.0000
# 79    Default  210.000000    不止  210.000000  27.0000  27.0000
# 375   Default  167.000000    小便  167.000000  26.0000  26.0000
# 240   Default  191.000000    分爲  191.000000  25.0000  25.0000
# 506   Default  225.000000    梧子  225.000000  24.0000  24.0000
# 464   Default  211.000000   末每服  211.000000  23.0000  23.0000
# 336   Default  239.000000   大每服  239.000000  22.0000  22.0000
# 428   Default  142.000000    方寸  142.000000  21.0000  21.0000
# 778   Default  117.000000    腫痛  117.000000  20.0000  20.0000
# 9     Default   97.000000    一切   97.000000  19.0000  19.0000
# 113   Default   95.000000   之千金   95.000000  18.0000  18.0000
# 364   Default   77.000000    婦人   77.000000  17.0000  17.0000
# 747   Default   81.000000    總錄   81.000000  16.0000  16.0000
# 981   Default   76.000000    麝香   76.000000  15.0000  15.0000
# 502   Default  111.000000    桐子  111.000000  14.0000  14.0000
# 324   Default  110.000000  外台秘要  110.000000  13.0000  13.0000
# 507   Default  110.000000    梧桐  110.000000  12.0000  12.0000
# 508   Default  110.000000   梧桐子  110.000000  11.0000  11.0000
# 640   Default   73.000000    疼痛   73.000000  10.0000  10.0000
# 223   Default  143.000000    兩爲  143.000000   9.0000   9.0000
# 320   Default   89.000000    地黃   89.000000   8.0000   8.0000
# 529   Default   71.000000    汲水   71.000000   7.0000   7.0000
# 85    Default   71.000000    不通   71.000000   6.0000   6.0000
# 745   Default   75.000000    綠豆   75.000000   5.0000   5.0000
# 237   Default   64.000000    出血   64.000000   4.0000   4.0000
# 40    Default   95.000000    三十   95.000000   3.0000   3.0000
# 71    Default   58.000000    不可   58.000000   2.0000   2.0000
# 172   Default   92.000000    五十   92.000000   1.0000   1.0000
# ...       ...         ...   ...         ...      ...      ...
# 859   Topic10   27.355532    螫傷   28.230381   2.5845  -3.9651
# 155   Topic10   26.111397    二七   26.980852   2.5832  -4.0117
# 842   Topic10   24.215452    蘿蔔   25.086132   2.5807  -4.0871
# 386   Topic10   24.276020    尿血   25.154971   2.5804  -4.0846
# 187   Topic10   23.848095    人參   24.727736   2.5798  -4.1023
# 298   Topic10   22.838546    咬傷   23.711495   2.5785  -4.1456
# 645   Topic10   28.957862  痛不可忍   30.089235   2.5777  -3.9082
# 83    Topic10   21.935411    不能   22.808565   2.5770  -4.1859
# 403   Topic10   21.059798    心鑑   21.931833   2.5754  -4.2267
# 426   Topic10   18.156253    斑蝥   19.028161   2.5691  -4.3750
# 527   Topic10   17.001245    水調   17.869747   2.5662  -4.4408
# 69    Topic10   18.645922    不出   19.641942   2.5640  -4.3484
# 427   Topic10   16.070115    方同   16.947703   2.5628  -4.4971
# 268   Topic10   15.241208    半煎   16.112719   2.5604  -4.5500
# 344   Topic10   15.004634   大腸脫   15.873808   2.5597  -4.5657
# 769   Topic10   15.895579    胡粉   16.823968   2.5592  -4.5080
# 414   Topic10   15.133333    指甲   16.023411   2.5589  -4.5571
# 840   Topic10   14.679216    藜蘆   15.567117   2.5573  -4.5876
# 696   Topic10   13.948410    直指   14.817038   2.5556  -4.6387
# 990   Topic10   13.863008    黃柏   14.736756   2.5549  -4.6448
# 522   Topic10   13.739392    水服   14.619184   2.5539  -4.6538
# 517   Topic10   13.400597    毒蛇   14.271461   2.5530  -4.6787
# 111   Topic10   13.352057   之冷即   14.220467   2.5530  -4.6824
# 70    Topic10   13.366073    不利   14.237125   2.5529  -4.6813
# 233   Topic10   22.370092    冷水   27.096299   2.4243  -4.1663
# 683   Topic10   23.894792    百合   30.901891   2.3588  -4.1004
# 979   Topic10   22.280346    鲫魚   32.205319   2.2476  -4.1703
# 835   Topic10   24.920880    薑汁   41.273878   2.1115  -4.0583
# 566   Topic10   22.368052    漿水   38.063810   2.0844  -4.1664
# 6     Topic10   17.507171   一兩爲   34.557248   1.9360  -4.4114
#
# [404 rows x 6 columns], token_table=      Topic      Freq  Term
# term
# 1         3  0.949337    一丸
# 2         5  0.973940    一二
# 4         6  0.969183    一個
# 5         8  0.956762    一兩
# 6         3  0.463000   一兩爲
# 6        10  0.520875   一兩爲
# 8         2  0.840081   一分爲
# 8         3  0.120012   一分爲
# 9         7  0.995929    一切
# 10        7  0.975578    一升
# 14        1  0.123797    一大
# 14        3  0.866578    一大
# 17        8  0.969779    一小
# 18        6  0.976036    一斤
# 22        2  0.352649    一枚
# 22        6  0.032059    一枚
# 22        9  0.609121    一枚
# 25        5  0.973531    一盞
# 27        4  0.989795    一錢
# 28        7  0.268113   一錢爲
# 28        8  0.706843   一錢爲
# 32        6  0.943460    七日
# 40        1  0.994946    三十
# 48        1  0.959046    三服
# 49        2  0.908426  三服千金
# 52        2  0.938291    三次
# 64        1  0.983439    下痢
# 66        8  0.971908    下血
# 67        2  0.929495    下部
# 68        3  0.989112    不下
# ...     ...       ...   ...
# 960       7  0.920978    風瘡
# 963       2  0.942165    風蟲
# 966       1  0.944758    飲下
# 966       3  0.028629    飲下
# 967       1  0.216873    飲服
# 967       8  0.759054    飲服
# 968       8  0.052187    飲水
# 968       9  0.939360    飲水
# 971       8  0.914756    香油
# 974       3  0.943682    驚風
# 976       5  0.960984    鬭煮
# 977       9  0.958920    魚骨
# 979       1  0.062102    鲫魚
# 979       3  0.031051    鲫魚
# 979       8  0.217355    鲫魚
# 979      10  0.683117    鲫魚
# 981       7  0.989287    麝香
# 984       1  0.347378    麻子
# 984       4  0.627521    麻子
# 984       5  0.011206    麻子
# 984       7  0.011206    麻子
# 986       4  0.961870    麻油
# 989       9  0.900868    黃丹
# 990      10  0.950006    黃柏
# 991       1  0.981805    黃連
# 992       4  0.935235    黍米
# 993       1  0.111927    黑豆
# 993       7  0.858105    黑豆
# 995       6  0.956949    鼻中
# 997       3  0.968042    鼻血
#
# [448 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 10, 8, 7, 9, 5, 3, 4, 6, 1])

# %%
tmp1 = lda.fit_transform(tf)
tmp2 = nmf.fit_transform(tfidf)
# Out:
# /home/tmu/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)

# %%
import numpy as np

for i in range(tmp1.shape[0]):
    if np.where(tmp1[i] == np.max(tmp1[i]))[0][0] != np.where(tmp2[i] == np.max(tmp2[i]))[0][0]:
        print(i, np.where(tmp1[i] == np.max(tmp1[i]))[0][0], np.where(tmp2[i] == np.max(tmp2[i]))[0][0])

# %%
tmp2[20]
# Out:
# array([0.        , 0.00020337, 0.        ])

# %%
df.shape
# Out:
# (5815, 3)

# %%
tmp1.shape
# Out:
# (5815, 3)

# %%
tmp2.shape
# Out:
# (5815, 3)
